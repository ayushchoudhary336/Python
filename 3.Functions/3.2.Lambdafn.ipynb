# %% [markdown]
# Lambda Function in Python

# %%
## syntax

lambda arguments :expression

## example

addition=lambda a,b:a+b

print(type(addition))
addition(2,3)
# Out:
# <class 'function'>
# 5

# %%
## map funtion in python- It applies a function to all items in a list

numbers=[1,2,3,4,5]

list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers1=[1,2,3]
numbers2=[4,5,6]

added_numbers=list(map(lambda x,y:x+y,numbers1,numbers2))
print(added_numbers)
# Out:
# [5, 7, 9]

# %%
 ## map() to convert a list of strings to integers
str_numbers = ['1','2','3','4']
int_numbers = list(map(int,str_numbers))

print(int_numbers)
# Out:
# [1, 2, 3, 4]
