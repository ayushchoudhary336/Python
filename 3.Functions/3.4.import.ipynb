# %% [markdown]
# Importing Modules in python

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(81))
print(pi)
# Out:
# 9.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(225))
print(pi)
# Out:
# 15.0
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5
