# %% [markdown]
# Understanding exceptions

# %% [markdown]
# Exception handling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program.This lesson will cover the bsics of exceptions, including how to use try, except, else and finally blocks.

# %% [markdown]
# exceptions-exceptions are the events that disrupts the normal flow of the error
#
# common exception are :-
# ZeroDisionError-Divided by zero
# FileNOtFOUND ERROR-file not found

# %%
## exceptions handling by using try , except block

try : 
  a=b
except:
  print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try : 
  a=b
except NameError as ex:
  print(ex)
# Out:
# name 'b' is not defined

# %%
## Exception keyword

try:
  result=1/2
  a=c
except Exception as ex:
  print(ex)
# Out:
# name 'c' is not defined

# %%
try:
  num=int(input("Enter a number"))
  result=10/num
except ValueError:
  print("This is not a valid number")  
except ZeroDivisionError:
  print("You can't divide by zero")
except Exception as ex:
  print(ex)
else:
  print(f"The Result is {result}")
finally:
  print("Execution complete")
# Out:
# The Result is 1.0
# Execution complete

# %%
### file handling and exception handling

try:
  file=open('example.txt','r')
  content=file.read()
  a=b
  print(content)

except FileNotFoundError:
  print("The file does not exists")

except Exception as ex:
  print(ex)  
 

finally:
  if 'file' in locals() or not file.closed():
    file.close()
    print('file close')
# Out:
# name 'b' is not defined
# file close
