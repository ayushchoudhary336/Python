# %%
## Basic syntax rules in Python
## case sensitivity - Python is case sensitivity

name="ayush"
print(name)
# Out:
# ayush

# %%
## line continuation

total=1+23+3+4+35+6+7+\
4+5+6
print(total)
# Out:
# 94

# %%
## variable assigned in python 

age=21
name="ayush"

print(age)
print(name)
# Out:
# 21
# ayush

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## code examples of indentataion

if True:
  print("correct indentataion")
  if False:
    print("This wont print")
  print("This will print")

print("Outside the if block")
# Out:
# correct indentataion
# This will print
# Outside the if block
