# %%
print("hello")
# Out:
# hello

# %%
a=45
b=15

add_result = a+b
sub_result = a-b
mult_result  = a*b
div_result = a/b
floor_div_result=a//b
modulus_result=a%b
exponent_results= a**b

print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_results)
# Out:
# 60
# 30
# 675
# 3.0
# 3
# 0
# 6283298708943145751953125

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %%
## comparision operators
## == Equalto operators

a=10
b=10

a==b
# Out:
# True

# %% [markdown]
# Logical opeartors

# %%
## and, not , or operators
X=True
Y=False

results = X and Y
print(results)
# Out:
# False

# %%
## or 

X=True
Y=False

results = X or Y
print(results)
# Out:
# True

# %%
## not

x = True
not X
# Out:
# False
