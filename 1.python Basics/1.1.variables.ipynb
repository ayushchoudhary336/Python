# %%
## declaring and assigning variables

name="Ayush"
age=20
height=6.1
is_student=True

print("name: ",name)
print("age: ",age)
print("height: ",height)
# Out:
# name:  Ayush
# age:  20
# height:  6.1

# %%
## type checking and conversion
type(height)
# Out:
# float

# %%
print(type(age))

# type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 20
# <class 'str'>

# %%
age = input("what is the age : ")
print(age,type(age))
# Out:
# 25 <class 'str'>

# %%
# common error

result="hello" + str(5)
print(result)
# Out:
# hello5
