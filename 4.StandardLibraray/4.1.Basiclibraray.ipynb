# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(["apple","cherry"]))
# Out:
# 9
# apple

# %%
## file and Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\ayush\Desktop\Python\4.StandardLibraray

# %%
os.mkdir("test_dir")

# %%
## high level operations on files and collection of files
import shutil
shutil.copyfile('sample.txt','final.txt')
# Out:
# 'final.txt'

# %%
## Data Searialization
import json
data={'name':"Ayush",'age':21}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Ayush", "age": 21}
# <class 'str'>
# {'name': 'Ayush', 'age': 21}
# <class 'dict'>

# %%
## csv

import csv
with open('example.csv',mode='w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(['name','age'])
  writer.writerow(['krish',32])

with open('example.csv',mode='r') as file:
  reader=csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
## datetime

from datetime import *
now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-02 03:13:41.736334
# 2026-03-01 03:13:41.736334

# %%
##time
